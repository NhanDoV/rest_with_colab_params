# %% [markdown]
# [References](https://colab.research.google.com/notebooks/forms.ipynb#scrollTo=bf5LUmgZt-kT)
#
# ## 1. Raw fields

# %%
R0 = 3.14 #@param type: "text"

# %% [markdown]
# ![image.png](attachment:3a4918cf-45c2-48e7-8eb3-b3b7b86ab1dc.png)
#
# Noting that these features have not been supported when using normally notebook

# %%
text = 'your string, such as NhanDV' #@param {type:"string"}

# %% [markdown]
# ![image.png](attachment:501f3f8d-4e1e-40f4-8017-27d828426fb0.png)

# %%
dropdown = '1st option: DS' #@param ["1st option: DS", "2nd option: DE", "3rd option: DA"]

# %% [markdown]
# ![image.png](attachment:51b53db9-850c-490f-ac81-60fa089a8a6b.png)

# %%
text_and_then_dropdown = 'value' #@param ["1st optn", "2nd optn", "3rd optn"] {allow-input: true}

# %% [markdown]
# ![image.png](attachment:02fc6e91-077a-40fe-9e31-66adb5dec8a1.png)

# %% [markdown]
# ### Summary

# %%
# @title String fields

text = 'value' #@param {type:"string"}
dropdown = '1st optn' #@param ["1st optn", "2nd optn", "3rd optn"]
text_and_then_dropdown = 'value' #@param ["1st optn", "2nd optn", "3rd optn"] {allow-input: true}

print(text)
print(dropdown)
print(text_and_then_dropdown)

# %% [markdown]
# ![image.png](attachment:5df5bfcc-ea30-4b2d-b8f4-c133b3661201.png)

# %% [markdown]
# ## 2. Raw fields

# %% [markdown]
# ## 3. Number fields

# %%
R0 = 3.14 #@param {type:"slider", min:0.9, max:5, step:0.01}

# %% [markdown]
# ![image.png](attachment:5f37983e-71a4-4038-ac86-a44f7bc703b4.png)
